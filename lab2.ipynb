# %% [markdown]
# # Do you remember what do we mean by tokenization?
# Yes, in summary, its cutting character sequence into word tokens

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Write whole python script here

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text=" Welcome readers. I hope you find it interesting. Please do reply."
from nltk.tokenize import sent_tokenize
print(sent_tokenize(text))
text=" Welcome readers, I hope you find it interesting, Please do reply."
from nltk.tokenize import sent_tokenize
print(sent_tokenize(text))
# Out:
# [' Welcome readers.', 'I hope you find it interesting.', 'Please do reply.']
# [' Welcome readers, I hope you find it interesting, Please do reply.']

# %% [markdown]
# # How many sentence you had? __3__
#
# # How many sentence will we have if we replace full stop “.”
# # With “,” in text?___1____

# %%
import nltk
tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")
text="  Hello everyone. Hope all are fine and doing well. Hope you find the book interesting."
tokenizer.tokenize(text)
# Out:
# ['  Hello everyone.',
#  'Hope all are fine and doing well.',
#  'Hope you find the book interesting.']

# %% [markdown]
# # Exercise 1: Explore punkt folder to see which languages are supported by default in nltk/tokenizer.

# %%
from IPython.display import display
from PIL import Image


path = r'D:\photo\punkt.png'
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=601x427 at 0x20D01956E20>

# %% [markdown]
# # Exercise 2: Try to tokenize this sentence:
# Text= “ مرحبا بكم. نحن نتعلم اساسيات مبادئ
# استرجاع المعلومات."

# %%
Arabic_text="مرحبا بكم. نحن نتعلم اساسيات مبادئ استرجاع المعلومات."
tokenizer.tokenize(Arabic_text)
# Out:
# ['مرحبا بكم.', 'نحن نتعلم اساسيات مبادئ استرجاع المعلومات.']

# %% [markdown]
# # Tokenization of sentences into words

# %%
import nltk
text = nltk.word_tokenize("Welcome readers. I hope you find it interesting. Please do reply..»") 
print(text)
# Out:
# ['Welcome', 'readers', '.', 'I', 'hope', 'you', 'find', 'it', 'interesting', '.', 'Please', 'do', 'reply', '..', '»']

# %% [markdown]
# # Exercise 3: Try to tokenize a given sentence from user into words. Use input() function to enter a text from keyboard.

# %%
Arabic=input("Please write a text: ")
textt = nltk.word_tokenize(Arabic) 
print(textt)
# Out:
# Please write a text: hi am aziz and your name ?
# ['hi', 'am', 'aziz', 'and', 'your', 'name', '?']

# %% [markdown]
# # Tokenization using TreebankWordTokenizer

# %%
import nltk
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize("how is your new job? I hope its good.")
# Out:
# ['how', 'is', 'your', 'new', 'job', '?', 'I', 'hope', 'its', 'good', '.']

# %% [markdown]
# # Tokenization using regular expressions

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer("[\w]+") 
tokenizer.tokenize("Don't hesitate to ask questions or send to me your question to mohsarem@gmail.com")
# Out:
# ['Don',
#  't',
#  'hesitate',
#  'to',
#  'ask',
#  'questions',
#  'or',
#  'send',
#  'to',
#  'me',
#  'your',
#  'question',
#  'to',
#  'mohsarem',
#  'gmail',
#  'com']

# %% [markdown]
# # Exercise 4: Modify the regular expression at step 3 above to find email address.

# %%
tokenizer=RegexpTokenizer("\S+@\S+") 
tokenizer.tokenize("Don't hesitate to ask questions or send to me your question to mohsarem@gmail.com")
# Out:
# ['mohsarem@gmail.com']

# %% [markdown]
# # Normalization

# %%
text=[" It is a pleasant evening.","Guests, who came from US arrived at the venue","Food was tasty."]
from nltk.tokenize import word_tokenize
tokenized_docs=[word_tokenize(doc) for doc in text]
print(tokenized_docs)
# Out:
# [['It', 'is', 'a', 'pleasant', 'evening', '.'], ['Guests', ',', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Food', 'was', 'tasty', '.']]

# %%
import re 
import string 
x=re.compile('[%s]' % re.escape(string.punctuation)) 
tokenized_docs_no_punctuation = [] 
for review in tokenized_docs: 
    new_review = []  
    for token in review: 
        new_token = x.sub(u'', token) 
        if not new_token == u'': 
             new_review.append(new_token) 
        tokenized_docs_no_punctuation.append(new_review) 
print(tokenized_docs_no_punctuation)
# Out:
# [['It', 'is', 'a', 'pleasant', 'evening'], ['It', 'is', 'a', 'pleasant', 'evening'], ['It', 'is', 'a', 'pleasant', 'evening'], ['It', 'is', 'a', 'pleasant', 'evening'], ['It', 'is', 'a', 'pleasant', 'evening'], ['It', 'is', 'a', 'pleasant', 'evening'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Guests', 'who', 'came', 'from', 'US', 'arrived', 'at', 'the', 'venue'], ['Foo
# ...

# %% [markdown]
# # Exercise 5. What is the role of re.compile(),re.escape()functions?

# %%
help(re.compile)
help(re.escape)
# Out:
# Help on function compile in module re:
#
# compile(pattern, flags=0)
#     Compile a regular expression pattern, returning a Pattern object.
#
# Help on function escape in module re:
#
# escape(pattern)
#     Escape special characters in a string.

# %% [markdown]
# # Exercise 6. Apply lower () function and upper() function on the sentence below:

# %%
text="NLTK allows you to convert Text into Lowercase and uppercase"
print(text.lower())
print(text[1].lower())

print(text[0].upper())
print(text.upper())
# Out:
# nltk allows you to convert text into lowercase and uppercase
# l
# N
# NLTK ALLOWS YOU TO CONVERT TEXT INTO LOWERCASE AND UPPERCASE

# %% [markdown]
# # Dealing with stop words

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stops=set(stopwords.words('english'))
words=["Don't",'hesitate','to','ask','questions']
[word for word in words if word not in stops]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ["Don't", 'hesitate', 'ask', 'questions']

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
print(stopwords.words('arabic'))
# Out:
# ['إذ', 'إذا', 'إذما', 'إذن', 'أف', 'أقل', 'أكثر', 'ألا', 'إلا', 'التي', 'الذي', 'الذين', 'اللاتي', 'اللائي', 'اللتان', 'اللتيا', 'اللتين', 'اللذان', 'اللذين', 'اللواتي', 'إلى', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'أم', 'أما', 'أما', 'إما', 'أن', 'إن', 'إنا', 'أنا', 'أنت', 'أنتم', 'أنتما', 'أنتن', 'إنما', 'إنه', 'أنى', 'أنى', 'آه', 'آها', 'أو', 'أولاء', 'أولئك', 'أوه', 'آي', 'أي', 'أيها', 'إي', 'أين', 'أين', 'أينما', 'إيه', 'بخ', 'بس', 'بعد', 'بعض', 'بك', 'بكم', 'بكم', 'بكما', 'بكن', 'بل', 'بلى', 'بما', 'بماذا', 'بمن', 'بنا', 'به', 'بها', 'بهم', 'بهما', 'بهن', 'بي', 'بين', 'بيد', 'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك', 'ثم', 'ثمة', 'حاشا', 'حبذا', 'حتى', 'حيث', 'حيثما', 'حين', 'خلا', 'دون', 'ذا', 'ذات', 'ذاك', 'ذان', 'ذانك', 'ذلك', 'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذو', 'ذوا', 'ذواتا', 'ذواتي', 'ذي', 'ذين', 'ذينك', 'ريث', 'سوف', 'سوى', 'شتان', 'عدا', 'عسى', 'عل', 'على', 'عليك', 'عليه', 'عما', 'عن', 'عند', 'غير', 'فإذا', 'فإن', 'فلا', 'فمن', 'في', 'فيم', 'فيما', 'فيه', 'فيها',
# ...

# %% [markdown]
# # Exercise 7. Tokenize and remove stop words from the sentence below:

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
text = "NLTK allows you to convert Text into Lowercase and uppercase. Don't hesitate to ask questions"
stop_words = set(stopwords.words('english'))  
word_tokens = word_tokenize(text) 
Tokenize_text = [w for w in word_tokens if not w in stop_words] 
Tokenize_text = [] 
for w in word_tokens: 
    if w not in stop_words: 
        Tokenize_text.append(w) 
print(Tokenize_text)
# Out:
# ['NLTK', 'allows', 'convert', 'Text', 'Lowercase', 'uppercase', '.', 'Do', "n't", 'hesitate', 'ask', 'questions']

# %% [markdown]
# # Home Task
# Exercise 8. Given a text in directory, demonstrate how to
# use NLTK to treat its content.

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
file = open(r'C:\Users\Aziz\Desktop\file.txt').read()
stop_words = set(stopwords.words('english'))  
word_tokens = word_tokenize(file) 
Tokenize_text = [w for w in word_tokens if not w in stop_words] 
Tokenize_text = [] 
for w in word_tokens: 
    if w not in stop_words: 
        Tokenize_text.append(w) 
print(Tokenize_text)
# Out:
# ['It', 'iterates', 'words', 'text', ',', 'word', 'already', 'exists', 'corpus', ',', 'increments', 'frequency', 'count', 'word']

# %%
print(file)
# Out:
# It iterates through all the words in the text, if the word already exists in the
# corpus, it increments the frequency count for the word
